# %%
# !git clone https://github.com/WongKinYiu/yolov9.git

# %%
# %cd yolov9
# Out:
# /home/ubuntu/S15/yolov9

# %%
# !pip install -r requirements.txt
# !pip install Pillow==9.5.0

# %%
# !unzip customdata.zip

# %%
# !python train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data data/customdata/data.yaml \
--weights weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# train: weights=weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=data/customdata/data.yaml, hyp=hyp.scratch-high.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.14 torch-2.2.0 CUDA:0 (Tesla T4, 14931MiB)
#
# ...

# %%
from IPython.display import Image

Image(filename=f"runs/train/exp3/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"runs/train/exp3/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"runs/train/exp3/val_batch0_pred.jpg", width=1000)
